# %%
# Importaciones necesarias

import numpy as np
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import scipy as sp

from sklearn.metrics.pairwise import cosine_similarity

# %%
# Se cargan los archivos parquet a utilizar
steam_games = pd.read_parquet('datos_parquet/steam_games.parquet')
users_items = pd.read_parquet('datos_parquet/user_items.parquet')
user_reviews = pd.read_parquet('datos_parquet/user_reviews.parquet')

# %%
# Se crean dos variables en las que se almacenan dos dataframes con las columnas a utilizar para la consulta

reviews = user_reviews[['user_id', 'id', 'sentiment_analysis']]

items = users_items[['id', 'item_name']]

items = items.drop_duplicates()

# %%
# Se crea un dataframe realizando un merge entre los dataset users_items y user_reviews
item_item = pd.merge(items,reviews, on='id', how='inner')

# Se renombra la columna id por item_id para facilitar la comprensión del dataset.
item_item.rename(columns={'id':'item_id'}, inplace=True)

# Se limita la cantidad de filas del dataset
item_recortado = item_item.head(40000)

item_recortado
# Out:
#        item_id       item_name                user_id  sentiment_analysis
# 0           10  Counter-Strike           Bennysaputra                   2
# 1           10  Counter-Strike               Monsta45                   1
# 2           10  Counter-Strike      76561198040188061                   2
# 3           10  Counter-Strike         mayshowganmore                   2
# 4           10  Counter-Strike  BestinTheWorldThund3r                   2
# ...        ...             ...                    ...                 ...
# 39995   386360           SMITE       wadiyatalknabeet                   2
# 39996   386360           SMITE               poofcorn                   2
# 39997   386360           SMITE      76561198111978125                   2
# 39998   386360           SMITE           AlphaPodbury                   2
# 39999   393420       Hurtworld      76561198094074209                   0
#
# [40000 rows x 4 columns]

# %%
# Se crea una matriz de utilidad donde las filas representan usuarios, las columnas representan los items y las celdas contendran las calificaciones o interacciones.
matriz_item = item_recortado.pivot_table(index=['user_id'], columns='item_name', values='sentiment_analysis')

# Se rellenan los nulos con ceros para luego almacenar los datos en una matriz dispersa
matriz_item = matriz_item.fillna(0)

matriz_item
# Out:
# item_name     100% Orange Juice  12 Labours of Hercules II: The Cretan Bull  \
# user_id
# --000--                     0.0                                         0.0
# --ace--                     0.0                                         0.0
# --ionex--                   0.0                                         0.0
# -2SV-vuLB-Kg                0.0                                         0.0
# -Azsael-                    0.0                                         0.0
# ...                         ...                                         ...
# zuzuga2003                  0.0                                         0.0
# zv_odd                      0.0                                         0.0
# zvanik                      0.0                                         0.0
# zynxgameth                  0.0                                         0.0
# zyr0n1c                     0.0                                         0.0
#
# item_name     16bit Trader  3079 -- Block Action RPG  \
# user_id
# --000--                0.0                       0.0
# --ace--                0.0                       0.0
# --ionex--              0.0                       0.0
# -2SV-vuLB-Kg           0.0                       0.0
# -Azsael-               0.0                       0.0
# ...                    ...                       ...
# zuzuga2003             0.0                       0.0
# zv_odd                 0.0                       0.0
# zvanik                 0.0                       0.0
# zynxgameth             0.0                       0.0
# zyr0n1c                0.0                       0.0
#
# item_name     3089 -- Futuristic Action RPG  \
# user_id
# --000--                                 0.0
# --ace--                                 0.0
# --ionex--                               0.0
# -2SV-vuLB-Kg                            0.0
# -Azsael-                                0.0
# ...                                     ...
# zuzuga2003                              0.0
# zv_odd                                  0.0
# zvanik                                  0.0
# zynxgameth                              0.0
# zyr0n1c                                 0.0
#
# item_name     3D Ultra Minigolf Adventures Deluxe  3DMark  99 Levels To Hell  \
# user_id
# --000--                                       0.0     0.0                0.0
# --ace--                                       0.0     0.0                0.0
# --ionex--                                     0.0     0.0                0.0
# -2SV-vuLB-Kg                                  0.0     0.0                0.0
# -Azsael-                                      0.0     0.0                0.0
# ...                                           ...     ...                ...
# zuzuga2003                                    0.0     0.0                0.0
# zv_odd                                        0.0     0.0                0.0
# zvanik                                        0.0     0.0                0.0
# zynxgameth                                    0.0     0.0                0.0
# zyr0n1c                                       0.0     0.0                0.0
#
# item_name     A New Beginning - Final Cut  A Virus Named TOM  ...  \
# user_id                                                       ...
# --000--                               0.0                0.0  ...
# --ace--                               0.0                0.0  ...
# --ionex--                             0.0                0.0  ...
# -2SV-vuLB-Kg                          0.0                0.0  ...
# -Azsael-                              0.0                0.0  ...
# ...                                   ...                ...  ...
# zuzuga2003                            0.0                0.0  ...
# zv_odd                                0.0                0.0  ...
# zvanik                                0.0                0.0  ...
# zynxgameth                            0.0                0.0  ...
# zyr0n1c                               0.0                0.0  ...
#
# item_name     XCOM: Enemy Unknown  Xpand Rally Xtreme  \
# user_id
# --000--                       0.0                 0.0
# --ace--                       0.0                 0.0
# --ionex--                     0.0                 0.0
# -2SV-vuLB-Kg                  2.0                 0.0
# -Azsael-                      0.0                 0.0
# ...                           ...                 ...
# zuzuga2003                    0.0                 0.0
# zv_odd                        0.0                 0.0
# zvanik                        0.0                 0.0
# zynxgameth                    0.0                 0.0
# zyr0n1c                       0.0                 0.0
#
# item_name     Yet Another Zombie Defense  Zeno Clash  Zeno Clash 2  \
# user_id
# --000--                              0.0         0.0           0.0
# --ace--                              0.0         0.0           0.0
# --ionex--                            0.0         0.0           0.0
# -2SV-vuLB-Kg                         0.0         0.0           0.0
# -Azsael-                             0.0         0.0           0.0
# ...                                  ...         ...           ...
# zuzuga2003                           0.0         0.0           0.0
# zv_odd                               0.0         0.0           0.0
# zvanik                               0.0         0.0           0.0
# zynxgameth                           0.0         0.0           0.0
# zyr0n1c                              0.0         0.0           0.0
#
# item_name     Zombie Army Trilogy  Zombie Driver  Zombies Monsters Robots  \
# user_id
# --000--                       0.0            0.0                      0.0
# --ace--                       0.0            0.0                      0.0
# --ionex--                     0.0            0.0                      0.0
# -2SV-vuLB-Kg                  0.0            0.0                      0.0
# -Azsael-                      0.0            0.0                      0.0
# ...                           ...            ...                      ...
# zuzuga2003                    0.0            0.0                      0.0
# zv_odd                        0.0            0.0                      0.0
# zvanik                        0.0            0.0                      0.0
# zynxgameth                    0.0            0.0                      0.0
# zyr0n1c                       0.0            0.0                      0.0
#
# item_name     Zuma's Revenge  resident evil 4 / biohazard 4
# user_id
# --000--                  0.0                            0.0
# --ace--                  0.0                            0.0
# --ionex--                0.0                            0.0
# -2SV-vuLB-Kg             0.0                            0.0
# -Azsael-                 0.0                            0.0
# ...                      ...                            ...
# zuzuga2003               0.0                            0.0
# zv_odd                   0.0                            0.0
# zvanik                   0.0                            0.0
# zynxgameth               0.0                            0.0
# zyr0n1c                  0.0                            0.0
#
# [20420 rows x 1047 columns]

# %%
# Se realiza una matriz dispersa a fin de mejorar espacio de almacenamiento y eficiencia de computo al almacenar solo los elementos distintos de cero.
matriz_sparse = sp.sparse.csr_matrix(matriz_item.values)

#item_similarity = cosine_similarity(matriz_sparse)

user_similarity = cosine_similarity(matriz_sparse.T)

user_sim = pd.DataFrame(user_similarity, index=matriz_item.columns, columns=matriz_item.columns)

# %%
type(user_similarity)
# Out:
# numpy.ndarray

# %%
user_sim
# Out:
# item_name                                   100% Orange Juice  \
# item_name
# 100% Orange Juice                                         1.0
# 12 Labours of Hercules II: The Cretan Bull                0.0
# 16bit Trader                                              0.0
# 3079 -- Block Action RPG                                  0.0
# 3089 -- Futuristic Action RPG                             0.0
# ...                                                       ...
# Zombie Army Trilogy                                       0.0
# Zombie Driver                                             0.0
# Zombies Monsters Robots                                   0.0
# Zuma's Revenge                                            0.0
# resident evil 4 / biohazard 4                             0.0
#
# item_name                                   12 Labours of Hercules II: The Cretan Bull  \
# item_name
# 100% Orange Juice                                                                  0.0
# 12 Labours of Hercules II: The Cretan Bull                                         1.0
# 16bit Trader                                                                       0.0
# 3079 -- Block Action RPG                                                           0.0
# 3089 -- Futuristic Action RPG                                                      0.0
# ...                                                                                ...
# Zombie Army Trilogy                                                                0.0
# Zombie Driver                                                                      0.0
# Zombies Monsters Robots                                                            0.0
# Zuma's Revenge                                                                     0.0
# resident evil 4 / biohazard 4                                                      0.0
#
# item_name                                   16bit Trader  \
# item_name
# 100% Orange Juice                                    0.0
# 12 Labours of Hercules II: The Cretan Bull           0.0
# 16bit Trader                                         0.0
# 3079 -- Block Action RPG                             0.0
# 3089 -- Futuristic Action RPG                        0.0
# ...                                                  ...
# Zombie Army Trilogy                                  0.0
# Zombie Driver                                        0.0
# Zombies Monsters Robots                              0.0
# Zuma's Revenge                                       0.0
# resident evil 4 / biohazard 4                        0.0
#
# item_name                                   3079 -- Block Action RPG  \
# item_name
# 100% Orange Juice                                                0.0
# 12 Labours of Hercules II: The Cretan Bull                       0.0
# 16bit Trader                                                     0.0
# 3079 -- Block Action RPG                                         1.0
# 3089 -- Futuristic Action RPG                                    0.0
# ...                                                              ...
# Zombie Army Trilogy                                              0.0
# Zombie Driver                                                    0.0
# Zombies Monsters Robots                                          0.0
# Zuma's Revenge                                                   0.0
# resident evil 4 / biohazard 4                                    0.0
#
# item_name                                   3089 -- Futuristic Action RPG  \
# item_name
# 100% Orange Juice                                                     0.0
# 12 Labours of Hercules II: The Cretan Bull                            0.0
# 16bit Trader                                                          0.0
# 3079 -- Block Action RPG                                              0.0
# 3089 -- Futuristic Action RPG                                         1.0
# ...                                                                   ...
# Zombie Army Trilogy                                                   0.0
# Zombie Driver                                                         0.0
# Zombies Monsters Robots                                               0.0
# Zuma's Revenge                                                        0.0
# resident evil 4 / biohazard 4                                         0.0
#
# item_name                                   3D Ultra Minigolf Adventures Deluxe  \
# item_name
# 100% Orange Juice                                                           0.0
# 12 Labours of Hercules II: The Cretan Bull                                  0.0
# 16bit Trader                                                                0.0
# 3079 -- Block Action RPG                                                    0.0
# 3089 -- Futuristic Action RPG                                               0.0
# ...                                                                         ...
# Zombie Army Trilogy                                                         0.0
# Zombie Driver                                                               0.0
# Zombies Monsters Robots                                                     0.0
# Zuma's Revenge                                                              0.0
# resident evil 4 / biohazard 4                                               0.0
#
# item_name                                   3DMark  99 Levels To Hell  \
# item_name
# 100% Orange Juice                              0.0                0.0
# 12 Labours of Hercules II: The Cretan Bull     0.0                0.0
# 16bit Trader                                   0.0                0.0
# 3079 -- Block Action RPG                       0.0                0.0
# 3089 -- Futuristic Action RPG                  0.0                0.0
# ...                                            ...                ...
# Zombie Army Trilogy                            0.0                0.0
# Zombie Driver                                  0.0                0.0
# Zombies Monsters Robots                        0.0                0.0
# Zuma's Revenge                                 0.0                0.0
# resident evil 4 / biohazard 4                  0.0                0.0
#
# item_name                                   A New Beginning - Final Cut  \
# item_name
# 100% Orange Juice                                                   0.0
# 12 Labours of Hercules II: The Cretan Bull                          0.0
# 16bit Trader                                                        0.0
# 3079 -- Block Action RPG                                            0.0
# 3089 -- Futuristic Action RPG                                       0.0
# ...                                                                 ...
# Zombie Army Trilogy                                                 0.0
# Zombie Driver                                                       0.0
# Zombies Monsters Robots                                             0.0
# Zuma's Revenge                                                      0.0
# resident evil 4 / biohazard 4                                       0.0
#
# item_name                                   A Virus Named TOM  ...  \
# item_name                                                      ...
# 100% Orange Juice                                         0.0  ...
# 12 Labours of Hercules II: The Cretan Bull                0.0  ...
# 16bit Trader                                              0.0  ...
# 3079 -- Block Action RPG                                  0.0  ...
# 3089 -- Futuristic Action RPG                             0.0  ...
# ...                                                       ...  ...
# Zombie Army Trilogy                                       0.0  ...
# Zombie Driver                                             0.0  ...
# Zombies Monsters Robots                                   0.0  ...
# Zuma's Revenge                                            0.0  ...
# resident evil 4 / biohazard 4                             0.0  ...
#
# item_name                                   XCOM: Enemy Unknown  \
# item_name
# 100% Orange Juice                                           0.0
# 12 Labours of Hercules II: The Cretan Bull                  0.0
# 16bit Trader                                                0.0
# 3079 -- Block Action RPG                                    0.0
# 3089 -- Futuristic Action RPG                               0.0
# ...                                                         ...
# Zombie Army Trilogy                                         0.0
# Zombie Driver                                               0.0
# Zombies Monsters Robots                                     0.0
# Zuma's Revenge                                              0.0
# resident evil 4 / biohazard 4                               0.0
#
# item_name                                   Xpand Rally Xtreme  \
# item_name
# 100% Orange Juice                                          0.0
# 12 Labours of Hercules II: The Cretan Bull                 0.0
# 16bit Trader                                               0.0
# 3079 -- Block Action RPG                                   0.0
# 3089 -- Futuristic Action RPG                              0.0
# ...                                                        ...
# Zombie Army Trilogy                                        0.0
# Zombie Driver                                              0.0
# Zombies Monsters Robots                                    0.0
# Zuma's Revenge                                             0.0
# resident evil 4 / biohazard 4                              0.0
#
# item_name                                   Yet Another Zombie Defense  \
# item_name
# 100% Orange Juice                                             0.000000
# 12 Labours of Hercules II: The Cretan Bull                    0.000000
# 16bit Trader                                                  0.000000
# 3079 -- Block Action RPG                                      0.000000
# 3089 -- Futuristic Action RPG                                 0.000000
# ...                                                                ...
# Zombie Army Trilogy                                           0.050395
# Zombie Driver                                                 0.000000
# Zombies Monsters Robots                                       0.000000
# Zuma's Revenge                                                0.000000
# resident evil 4 / biohazard 4                                 0.000000
#
# item_name                                   Zeno Clash  Zeno Clash 2  \
# item_name
# 100% Orange Juice                                  0.0           0.0
# 12 Labours of Hercules II: The Cretan Bull         0.0           0.0
# 16bit Trader                                       0.0           0.0
# 3079 -- Block Action RPG                           0.0           0.0
# 3089 -- Futuristic Action RPG                      0.0           0.0
# ...                                                ...           ...
# Zombie Army Trilogy                                0.0           0.0
# Zombie Driver                                      0.0           0.0
# Zombies Monsters Robots                            0.0           0.0
# Zuma's Revenge                                     0.0           0.0
# resident evil 4 / biohazard 4                      0.0           0.0
#
# item_name                                   Zombie Army Trilogy  \
# item_name
# 100% Orange Juice                                           0.0
# 12 Labours of Hercules II: The Cretan Bull                  0.0
# 16bit Trader                                                0.0
# 3079 -- Block Action RPG                                    0.0
# 3089 -- Futuristic Action RPG                               0.0
# ...                                                         ...
# Zombie Army Trilogy                                         1.0
# Zombie Driver                                               0.0
# Zombies Monsters Robots                                     0.0
# Zuma's Revenge                                              0.0
# resident evil 4 / biohazard 4                               0.0
#
# item_name                                   Zombie Driver  \
# item_name
# 100% Orange Juice                                     0.0
# 12 Labours of Hercules II: The Cretan Bull            0.0
# 16bit Trader                                          0.0
# 3079 -- Block Action RPG                              0.0
# 3089 -- Futuristic Action RPG                         0.0
# ...                                                   ...
# Zombie Army Trilogy                                   0.0
# Zombie Driver                                         1.0
# Zombies Monsters Robots                               0.0
# Zuma's Revenge                                        0.0
# resident evil 4 / biohazard 4                         0.0
#
# item_name                                   Zombies Monsters Robots  \
# item_name
# 100% Orange Juice                                               0.0
# 12 Labours of Hercules II: The Cretan Bull                      0.0
# 16bit Trader                                                    0.0
# 3079 -- Block Action RPG                                        0.0
# 3089 -- Futuristic Action RPG                                   0.0
# ...                                                             ...
# Zombie Army Trilogy                                             0.0
# Zombie Driver                                                   0.0
# Zombies Monsters Robots                                         1.0
# Zuma's Revenge                                                  0.0
# resident evil 4 / biohazard 4                                   0.0
#
# item_name                                   Zuma's Revenge  \
# item_name
# 100% Orange Juice                                      0.0
# 12 Labours of Hercules II: The Cretan Bull             0.0
# 16bit Trader                                           0.0
# 3079 -- Block Action RPG                               0.0
# 3089 -- Futuristic Action RPG                          0.0
# ...                                                    ...
# Zombie Army Trilogy                                    0.0
# Zombie Driver                                          0.0
# Zombies Monsters Robots                                0.0
# Zuma's Revenge                                         1.0
# resident evil 4 / biohazard 4                          0.0
#
# item_name                                   resident evil 4 / biohazard 4
# item_name
# 100% Orange Juice                                                     0.0
# 12 Labours of Hercules II: The Cretan Bull                            0.0
# 16bit Trader                                                          0.0
# 3079 -- Block Action RPG                                              0.0
# 3089 -- Futuristic Action RPG                                         0.0
# ...                                                                   ...
# Zombie Army Trilogy                                                   0.0
# Zombie Driver                                                         0.0
# Zombies Monsters Robots                                               0.0
# Zuma's Revenge                                                        0.0
# resident evil 4 / biohazard 4                                         1.0
#
# [1047 rows x 1047 columns]

# %%
#item_sim_df = pd.DataFrame(item_similarity, index=matriz_item.index, columns=matriz_item.index)
#item_sim_df

# %%
def cinco_recomendaciones2(item_id):
    
    # Se verifica si el ID de juego proporcionado existe en el DataFrame
    if int(item_id) not in item_recortado['item_id'].values:
        return f"Error: El ID de juego {item_id} no se encuentra en el DataFrame."
    
    # Verificar si hay suficientes datos para calcular recomendaciones
    if len(user_sim) <= item_id:
        return "Error: No hay suficientes datos para calcular recomendaciones."
    
    else:
            # Obtener el índice del juego en la matriz
        id_to_name = item_recortado.loc[item_recortado['item_id'] == item_id, 'item_name']
        
        item_name = id_to_name.values[0]
    
        encabezado = f'Juegos similares a {item_name}:'
    
        for item in user_sim.sort_values(by=item_name, ascending=False).index[1:6]:
            encabezado += f'\n-{item}'
    print (encabezado)

# %%
cinco_recomendaciones2(10)
# Out:
# Juegos similares a Counter-Strike:
# -Half-Life Deathmatch: Source
# -Serious Sam Classic: The First Encounter
# -Half-Life: Blue Shift
# -Day of Defeat
# -Counter-Strike: Source

# %%
# Se convierte el DataFrame a una tabla de Arrow para posteriormente comprimirlo en parquet
table = pa.Table.from_pandas(user_sim)

# Se especifica el nombre del archivo Parquet y comprime con snappy
parquet_file = 'datos_parquet/user_sim.parquet'
pq.write_table(table, parquet_file, compression='snappy')

# %%
# Se convierte el DataFrame a una tabla de Arrow para posteriormente comprimirlo en parquet
table = pa.Table.from_pandas(item_recortado)

# Se especifica el nombre del archivo Parquet y comprime con snappy
parquet_file = 'datos_parquet/item_chunk.parquet'
pq.write_table(table, parquet_file, compression='snappy')

# %%
item_recortado = pd.read_parquet('datos_parquet/user_items.parquet')

item_recortado
# Out:
#                    user_id  items_count           steam_id      id  \
# 0        76561197970982479          277  76561197970982479      10
# 1        76561197970982479          277  76561197970982479      20
# 2        76561197970982479          277  76561197970982479      30
# 3        76561197970982479          277  76561197970982479      40
# 4        76561197970982479          277  76561197970982479      50
# ...                    ...          ...                ...     ...
# 5170009  76561198329548331            7  76561198329548331  346330
# 5170010  76561198329548331            7  76561198329548331  373330
# 5170011  76561198329548331            7  76561198329548331  388490
# 5170012  76561198329548331            7  76561198329548331  521570
# 5170013  76561198329548331            7  76561198329548331  519140
#
#                              item_name  playtime_forever  playtime_2weeks
# 0                       Counter-Strike               6.0              0.0
# 1                Team Fortress Classic               0.0              0.0
# 2                        Day of Defeat               7.0              0.0
# 3                   Deathmatch Classic               0.0              0.0
# 4            Half-Life: Opposing Force               0.0              0.0
# ...                                ...               ...              ...
# 5170009                   BrainBread 2               0.0              0.0
# 5170010                    All Is Dust               0.0              0.0
# 5170011  One Way To Die: Steam Edition               3.0              3.0
# 5170012          You Have 10 Seconds 2               4.0              4.0
# 5170013                     Minds Eyes               3.0              3.0
#
# [5153209 rows x 7 columns]

# %%
items_items_ML = pd.read_parquet('datos_parquet/user_items2.parquet')

items_items_ML
# Out:
#                    user_id  items_count           steam_id      id  \
# 4205846       ThatKidRanga          681  76561198035551917  227080
# 977603   76561197981425218          109  76561197981425218  228200
# 3170639  76561197970733576           61  76561197970733576   43110
# 1343254       chloejacobsx         1003  76561198041310702  205950
# 3001052  76561198050051046           66  76561198050051046  291550
# ...                    ...          ...                ...     ...
# 2671627  76561198055712539           49  76561198055712539   65800
# 455985       GoldenCookies           86  76561198087478253  246280
# 4680548  76561198065886270           99  76561198065886270  349700
# 1365084         GilfSlayer           27  76561198096628949  273110
# 554370               Arpek           80  76561198095826521  211820
#
#                                      item_name  playtime_forever  \
# 4205846                              Papo & Yo               9.0
# 977603   Company of Heroes (New Steam Version)            4312.0
# 3170639                             Metro 2033              14.0
# 1343254                          Jet Set Radio              28.0
# 3001052                             Brawlhalla            1354.0
# ...                                        ...               ...
# 2671627                      Dungeon Defenders             584.0
# 455985                              Happy Wars              40.0
# 4680548                              Aftermath               0.0
# 1365084          Counter-Strike Nexon: Zombies               0.0
# 554370                               Starbound            3397.0
#
#          playtime_2weeks
# 4205846              0.0
# 977603               0.0
# 3170639              0.0
# 1343254              0.0
# 3001052            692.0
# ...                  ...
# 2671627              0.0
# 455985               0.0
# 4680548              0.0
# 1365084              0.0
# 554370               0.0
#
# [800000 rows x 7 columns]
