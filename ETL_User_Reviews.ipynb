# %% [markdown]
# ### LIBRERIAS

# %%
import pandas as pd
import json
import ast
import warnings
import pyarrow as pa
import pyarrow.parquet as pq
warnings.filterwarnings('ignore')

# %% [markdown]
# #### ETL SOBRE USER_REVIEWS

# %%
# Se carga el json de user_reviews y se realiza una lectura linea a linea que se irá almacenando 
# en una lista para luego convertirla en un dataframe pandas
user_reviews = 'datos_json/australian_user_reviews.json'

listado = []

with open(user_reviews, 'r', encoding= 'utf-8') as archivo:
    for linea in archivo.readlines():
        listado.append(ast.literal_eval(linea))

# Se crea un dataframe con el listado de lineas
dfUserReviews = pd.DataFrame(listado)

# Se guarda en formato csv para mejorar tiempos de carga y flujo de trabajo.
dfUserReviews.to_csv('json_a_csv/australian_user_reviews.csv', index=False)

# %%
#Se carga el csv previamente creado.
userReviews = pd.read_csv("json_a_csv/australian_user_reviews.csv")

userReviews
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 2              evcentric             http://steamcommunity.com/id/evcentric
# 3                  doctr                 http://steamcommunity.com/id/doctr
# 4              maplemage             http://steamcommunity.com/id/maplemage
# ...                  ...                                                ...
# 25794  76561198306599751  http://steamcommunity.com/profiles/76561198306...
# 25795           Ghoustik              http://steamcommunity.com/id/Ghoustik
# 25796  76561198310819422  http://steamcommunity.com/profiles/76561198310...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#                                                  reviews
# 0      [{'funny': '', 'posted': 'Posted November 5, 2...
# 1      [{'funny': '', 'posted': 'Posted June 24, 2014...
# 2      [{'funny': '', 'posted': 'Posted February 3.',...
# 3      [{'funny': '', 'posted': 'Posted October 14, 2...
# 4      [{'funny': '3 people found this review funny',...
# ...                                                  ...
# 25794  [{'funny': '', 'posted': 'Posted May 31.', 'la...
# 25795  [{'funny': '', 'posted': 'Posted June 17.', 'l...
# 25796  [{'funny': '1 person found this review funny',...
# 25797  [{'funny': '', 'posted': 'Posted July 21.', 'l...
# 25798  [{'funny': '1 person found this review funny',...
#
# [25799 rows x 3 columns]

# %%
# Se verifica que no haya nulos
userReviews.isnull().any()
# Out:
# user_id     False
# user_url    False
# reviews     False
# dtype: bool

# %%
# Se importa la funcion literal_eval para evaluar expresiones literales de tipo str
from ast import literal_eval

# Se aplica el literal_eval a toda la columna reviews convirtiendo las cadenas en estructuras de datos
userReviews['reviews'] = userReviews['reviews'].apply(literal_eval)

# Se aplica el metodo explode a la columna reviews para dividir las listas en filas separadas y se replican las demas columnas para cada fila resultante.
filasReviews = userReviews.explode('reviews')

# Se desglosan las columnas anidadas utilizando el metodo json_normalize.
desgloseColumnas = pd.json_normalize(filasReviews['reviews'])

# Se reinician los indices para posteriormente realizar un join
filasReviews = filasReviews.reset_index(drop=True)

# Se combina filasReviews y desgloseColumnas
userReviews = filasReviews.join(desgloseColumnas)

# Se reinician los indices luego de realizar el join
userReviews = userReviews.reset_index(drop=True)

# Se eliminan las columnas user_url y reviews
userReviewsFinal = userReviews.drop(['user_url','reviews'], axis=1)

# %%
# Se hace una revision para ver si existen duplicados
userReviewsFinal[userReviewsFinal.duplicated()]
# Out:
#                  user_id funny                      posted  \
# 1114          bokkkbokkk        Posted September 24, 2015.
# 2894          ImSeriouss          Posted January 10, 2014.
# 2895          ImSeriouss          Posted January 10, 2014.
# 2896          ImSeriouss         Posted December 17, 2014.
# 2897          ImSeriouss          Posted January 13, 2014.
# ...                  ...   ...                         ...
# 44456  76561198092022514                    Posted July 3.
# 44457  76561198092022514                    Posted June 1.
# 44458  76561198092022514           Posted August 17, 2014.
# 44459  76561198092022514         Posted February 17, 2014.
# 44603     SuchGayMuchWow             Posted July 18, 2015.
#
#                          last_edited item_id  \
# 1114                                  346110
# 2894                                  218620
# 2895                                  105600
# 2896                                     570
# 2897                                  211820
# ...                              ...     ...
# 44456                                 422400
# 44457                                 218620
# 44458                                 261820
# 44459                                 224260
# 44603  Last edited December 1, 2015.     730
#
#                                               helpful recommend  \
# 1114   1 of 1 people (100%) found this review helpful      True
# 2894    1 of 3 people (33%) found this review helpful      True
# 2895     0 of 2 people (0%) found this review helpful      True
# 2896                                   No ratings yet      True
# 2897                                   No ratings yet      True
# ...                                               ...       ...
# 44456                                  No ratings yet      True
# 44457                                  No ratings yet      True
# 44458                                  No ratings yet      True
# 44459                                  No ratings yet      True
# 44603                                  No ratings yet      True
#
#                                                   review
# 1114                                                 yep
# 2894              Good graphics, fun heists! A bit laggy
# 2895   So fun! DEFINITELY NOT RIP OFF OF MINECRAFT! e...
# 2896                                          bobo pinoy
# 2897   If you want to play this game.. expect glithes...
# ...                                                  ...
# 44456  Muy entretenido y una coleccion de armas prome...
# 44457  Tiene una jugabilidad y tematica muy buena :D,...
# 44458  Buen juego, no importa el desarrrollo que tien...
# 44459  exelente aporte :D¡¡¡ es una buen mod basado e...
# 44603                10/10 too many children with mikes.
#
# [874 rows x 8 columns]

# %%
# Se verifica si los duplicados observados previamente son correctos utilizando el primer user_id duplicado
userReviewsFinal[userReviewsFinal['user_id']=='bokkkbokkk']
# Out:
#          user_id funny                      posted last_edited item_id  \
# 1113  bokkkbokkk        Posted September 24, 2015.              346110
# 1114  bokkkbokkk        Posted September 24, 2015.              346110
#
#                                              helpful recommend review
# 1113  1 of 1 people (100%) found this review helpful      True    yep
# 1114  1 of 1 people (100%) found this review helpful      True    yep

# %%
# Se aplica el metodo drop_duplicates 
userReviewsFinal= userReviewsFinal.drop_duplicates()

# %%
# Se consulta la información disponible del dataframe
userReviewsFinal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 58459 entries, 0 to 59332
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      58459 non-null  object
#  1   funny        58431 non-null  object
#  2   posted       58431 non-null  object
#  3   last_edited  58431 non-null  object
#  4   item_id      58431 non-null  object
#  5   helpful      58431 non-null  object
#  6   recommend    58431 non-null  object
#  7   review       58431 non-null  object
# dtypes: object(8)
# memory usage: 4.0+ MB

# %%
# Se modifica el tipo de la columna item_id
userReviewsFinal['item_id'] = userReviewsFinal['item_id'].astype('Int64')

# %%
# Se observa la media de nulos de cada columna.
userReviewsFinal.isnull().mean()
# Out:
# user_id        0.000000
# funny          0.000479
# posted         0.000479
# last_edited    0.000479
# item_id        0.000479
# helpful        0.000479
# recommend      0.000479
# review         0.000479
# dtype: float64

# %%
# Se almacenan los indices de los nulos en la columna id que no permiten realizar la transformacion del tipo de dato
nulos = userReviewsFinal[userReviewsFinal['recommend'].isna()].index

# Se utiliza la variable nulos donde almacene el indice de nulos para ubicar las filas correspondientes
userReviewsFinal.iloc[nulos]
# Out:
#                        user_id                             funny  \
# 137                      gdxsd                               NaN
# 177          76561198094224872                               NaN
# 2560         76561198074079694
# 10205             PintoProAlto  1 person found this review funny
# 14008        76561198064975700
# 15777                   mtmoss
# 19609                 zrustz16
# 20664               WardPearce
# 25593                     BM5K
# 26815              matrix12384
# 27252               roitethere
# 29044        76561198017761748
# 29052                DuffBeer1
# 29582                ethanol10
# 32619            starfleetbrat
# 33492             LegoBrownHat
# 34480  TheBlackHammersAssassin
# 40085         Spagggggetttttti
# 40164        76561198025976606
# 40227                davidsavy
# 41488                   temere
# 42632                   Sosaia  1 person found this review funny
# 45258        76561197993617677
# 51592        76561198067794298
# 54197               matrix1234
# 56299               Lotharrock  1 person found this review funny
# 58452        76561198121979833
# 58640        76561198130579057
#
#                            posted                   last_edited  item_id  \
# 137                           NaN                           NaN     <NA>
# 177                           NaN                           NaN     <NA>
# 2560     Posted October 17, 2015.                                 208090
# 10205      Posted April 21, 2014.                                    570
# 14008       Posted June 26, 2012.                                    440
# 15777     Posted January 9, 2014.                                 252490
# 19609        Posted July 7, 2014.                                 304930
# 20664            Posted March 18.                                 373360
# 25593        Posted July 7, 2014.                                 242920
# 26815        Posted May 24, 2013.  Last edited January 1, 2014.      570
# 27252    Posted January 10, 2014.                                    440
# 29044  Posted September 17, 2015.                                 385330
# 29052        Posted May 22, 2014.                                    730
# 29582         Posted February 11.                                 391540
# 32619          Posted February 4.                                 280790
# 33492     Posted August 14, 2015.                                 304930
# 34480    Posted January 15, 2014.                                 113200
# 40085        Posted May 23, 2012.                                  48700
# 40164       Posted July 21, 2013.                                 219640
# 40227   Posted December 26, 2013.                                 261980
# 41488      Posted April 25, 2014.                                   4000
# 42632             Posted July 10.                                 381210
# 45258         Posted February 12.                                 210970
# 51592    Posted January 21, 2015.                                 261640
# 54197    Posted January 24, 2014.                                    730
# 56299       Posted June 14, 2013.                                  99900
# 58452   Posted November 30, 2015.                                 209870
# 58640       Posted March 6, 2015.                                 230410
#
#                                               helpful recommend  \
# 137                                               NaN       NaN
# 177                                               NaN       NaN
# 2560                                   No ratings yet      True
# 10205  3 of 3 people (100%) found this review helpful      True
# 14008                                  No ratings yet      True
# 15777  1 of 1 people (100%) found this review helpful      True
# 19609   4 of 6 people (67%) found this review helpful      True
# 20664   3 of 5 people (60%) found this review helpful      True
# 25593                                  No ratings yet      True
# 26815                                  No ratings yet      True
# 27252  1 of 1 people (100%) found this review helpful      True
# 29044                                  No ratings yet      True
# 29052    0 of 1 people (0%) found this review helpful     False
# 29582    0 of 1 people (0%) found this review helpful      True
# 32619                                  No ratings yet      True
# 33492                                  No ratings yet      True
# 34480                                  No ratings yet      True
# 40085                                  No ratings yet      True
# 40164                                  No ratings yet      True
# 40227                                  No ratings yet     False
# 41488                                  No ratings yet      True
# 42632   2 of 4 people (50%) found this review helpful      True
# 45258   1 of 3 people (33%) found this review helpful      True
# 51592                                  No ratings yet      True
# 54197  1 of 1 people (100%) found this review helpful      True
# 56299  1 of 1 people (100%) found this review helpful      True
# 58452    0 of 2 people (0%) found this review helpful     False
# 58640                                  No ratings yet      True
#
#                                                   review
# 137                                                  NaN
# 177                                                  NaN
# 2560                             Best game with gore. =P
# 10205                                    belezura d jogo
# 14008                                          'tis good
# 15777  Rust is stil in uts early stages. For now, i h...
# 19609  Jogo divertido, graficos quadrados s2, tem um ...
# 20664  Very, Very Fun. One of the best games I have e...
# 25593  If you're into civilization-building (note the...
# 26815  Dota 2, hours of fun spent playing this game w...
# 27252                                           ice game
# 29044  This was awesome. Gameplay takes up about 2 ho...
# 29052                                   Great Game -7/25
# 29582  It's a nice game. It makes you think.Like the ...
# 32619  Negatives: Freemium - Yes its a free game, but...
# 33492  this is probably the best game i have ever pla...
# 34480  ITS AMAZING! Its a dungeon crawl with many twi...
# 40085                                        Just get it
# 40164              I like to chop of heads thus Chivalry
# 40227                          it is the worst game ever
# 41488                                        Pretty good
# 42632  This game is absolutly amazing ! It's new so d...
# 45258  Everything you've heard about this puzzle game...
# 51592  its fun sometimes boring but it can be alot of...
# 54197                                    cs go for free!
# 56299  es un buen juego es de rol para la gente que l...
# 58452                  that uninstall button was amazing
# 58640  All I can say is "Best Game Ever" I wish all f...

# %%
# Se analiza el dataset resultante a partir de los nulos y se procede a eliminar las filas 137 y 177 ya que las componen un 90% de datos nulos.
userReviewsFinal.drop(index=137,inplace=True)
userReviewsFinal.drop(index=177,inplace=True)

# %%
# Se procede a eliminar las columnas funny, Last_edited y helpful ya que no serán usadas por la API ni por el Sentiment Analysis.
userReviewsFinal = userReviewsFinal.drop(['funny','last_edited','helpful'], axis= 1)

# Se extrae el dato de la fecha de la columna posted y se lo transforma a datetime.
userReviewsFinal["posted"] = pd.to_datetime(userReviewsFinal["posted"].astype(str).str.replace(r'Posted |,|\.', '', regex=True), errors='coerce')

# Se aplica una interpolación cruzada para completar los valores faltantes.
userReviewsFinal['posted'] = userReviewsFinal['posted'].interpolate(method='linear', limit_area='inside')

# Se extrae el año de la columna posted y se crea una columna 
userReviewsFinal['review_year'] = userReviewsFinal['posted'].dt.year

# Se aplica el metodo drop a la columna posted ya que no será usada posteriormente.
userReviewsFinal.drop('posted', axis=1, inplace=True)

userReviewsFinal
# Out:
#                  user_id  item_id recommend  \
# 0      76561197970982479     1250      True
# 1      76561197970982479    22200      True
# 2      76561197970982479    43110      True
# 3                js41637   251610      True
# 4                js41637   227300      True
# ...                  ...      ...       ...
# 59328  76561198312638244       70      True
# 59329  76561198312638244   362890      True
# 59330        LydiaMorley   273110      True
# 59331        LydiaMorley      730      True
# 59332        LydiaMorley      440      True
#
#                                                   review  review_year
# 0      Simple yet with great replayability. In my opi...         2011
# 1                   It's unique and worth a playthrough.         2011
# 2      Great atmosphere. The gunplay can be a bit chu...         2011
# 3      I know what you think when you see this title ...         2014
# 4      For a simple (it's actually not all that simpl...         2013
# ...                                                  ...          ...
# 59328  a must have classic from steam definitely wort...         2015
# 59329  this game is a perfect remake of the original ...         2015
# 59330  had so much fun plaing this and collecting res...         2015
# 59331                                                 :D         2015
# 59332                                     so much fun :D         2015
#
# [58457 rows x 5 columns]

# %% [markdown]
# ### Sentiment Analyzer
#
# Al dataframe de User Reviews se le va a realizar un analisis de sentimiento para poder determinar en base a un modelo estadistico

# %% [markdown]
# ##### Importaciones

# %%
import nltk
nltk.download('vader_lexicon')

from nltk.sentiment import SentimentIntensityAnalyzer

sia = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to C:\Users\Nano
# [nltk_data]     L3AN\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Se almacenan los indices de los nulos en la columna review
reviewsNulos = userReviewsFinal[userReviewsFinal['review'].isnull()].index

# Se utiliza iloc para realizar una lectura y analisis de los nulos
userReviewsFinal.iloc[reviewsNulos]
# Out:
#                  user_id  item_id recommend  \
# 2562             Halio99      730      True
# 10207       PintoProAlto     4000      True
# 14011        H4unted_P3n      440      True
# 15779             mtmoss   286100      True
# 19611           zrustz16   265630      True
# 20666         WardPearce   319630      True
# 25595            BZ4LIFE   407250     False
# 26817  76561198052485823    99900      True
# 27254         roitethere   224260      True
# 29046   SkateboardSquats      730      True
# 29054          DuffBeer1    91310      True
# 29584          ethanol10   212800      True
# 32621      starfleetbrat   286340      True
# 33494         RedBearAKM   325610      True
# 34482  76561198086758138      440      True
# 40087  76561198048072743     1250      True
# 40166    lordchevycat101   322500      True
# 40229          fluxxenik    51100      True
# 41490             temere   245550      True
# 42634  76561198043068128   286340      True
# 45260  76561197993617677      440      True
# 51594         StillChong   376570      True
# 54199      zehterminator    72850      True
# 56301         Lotharrock     7940      True
# 58454  76561198121979833    48700      True
# 58642  76561198130874522      730      True
#
#                                                   review  review_year
# 2562   You either die a noob; repetitively. Or live l...         2015
# 10207                           melhor que pinto no lixo         2014
# 14011  Team Fortress 2 is a excellent FPS game that i...         2014
# 15779  Quite a good fun little game for a free to pla...         2014
# 19611                                        Muito bom !         2014
# 20666  This is one the best game I have played.The be...         2014
# 25595  Aweful gameplay; players take 2 seconds to res...         2014
# 26817  that's right Free to play!and have funny to yo...         2013
# 27254  What more could you ask for a zombie game, it ...         2015
# 29046  Step 1: Play gameStep 2: Get skinsStep 3: ????...         2014
# 29054  Dead Island is a very fun game where you go ar...         2013
# 29584  I cry everytime I play this game.Not because I...         2014
# 32621  It's a great start but it wasn't long enough t...         2014
# 33494  I love this game and the game play its better ...         2015
# 34482  Possibly the best multiplayer game ever create...         2014
# 40087  BEST GAME EVER!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!...         2013
# 40166  I see alot of people raving on in the reviews ...         2013
# 40229  Just like Counter Strike but F2P, plusit runs ...         2013
# 41490  Inspiring, although it was a bit depressing to...         2014
# 42634  CAN YOU ADD MUTIPLAYER PLSSSSSSSSSSSSSSSSSSSSS...         2014
# 45260       free, frenetic and full of vitamin pwnage.           2012
# 51594  Haven't been too immersed in a game for a long...         2013
# 54199  Now, let's be honest, this game is really real...         2014
# 56301  Muy bueno en competitivo y jugabilidad y no es...         2015
# 58454  i love this game even thought it only say 31 h...         2015
# 58642                                        Amaze balls         2015

# %%
# Se normaliza el texto a utilizar en el analisis de sentimiento.
userReviewsFinal['review'] = userReviewsFinal['review'].str.lower()

# Se transforma el tipo de la columna review a str.
userReviewsFinal['review'] = userReviewsFinal['review'].astype(str)

userReviewsFinal
# Out:
#                  user_id  item_id recommend  \
# 0      76561197970982479     1250      True
# 1      76561197970982479    22200      True
# 2      76561197970982479    43110      True
# 3                js41637   251610      True
# 4                js41637   227300      True
# ...                  ...      ...       ...
# 59328  76561198312638244       70      True
# 59329  76561198312638244   362890      True
# 59330        LydiaMorley   273110      True
# 59331        LydiaMorley      730      True
# 59332        LydiaMorley      440      True
#
#                                                   review  review_year
# 0      simple yet with great replayability. in my opi...         2011
# 1                   it's unique and worth a playthrough.         2011
# 2      great atmosphere. the gunplay can be a bit chu...         2011
# 3      i know what you think when you see this title ...         2014
# 4      for a simple (it's actually not all that simpl...         2013
# ...                                                  ...          ...
# 59328  a must have classic from steam definitely wort...         2015
# 59329  this game is a perfect remake of the original ...         2015
# 59330  had so much fun plaing this and collecting res...         2015
# 59331                                                 :d         2015
# 59332                                     so much fun :d         2015
#
# [58457 rows x 5 columns]

# %%
# Se crea una funcion para aplicar puntaje al texto ingresado.
def puntaje(texto):
    # Se verifica que texto no este vacio.
    if texto: # Se calcula el puntaje compuesto mediante la funcion polarity_scores.
        compound_score = sia.polarity_scores(texto)['compound']
        
        # Se evalúa el puntaje compuesto y devuelve el puntaje correspondiente.
        if compound_score >= 0.05:
            return 2  # Positivo
        elif compound_score <= -0.05:
            return 0  # Negativo
        else:
            return 1  # Neutral
    else:
        return 1  # valor por defecto si no hay reseña

# Se crea la columna sentiment_analysis donde se cargan los puntajes aplicados al texto de la columna review 
userReviewsFinal['sentiment_analysis'] = userReviewsFinal['review'].apply(puntaje)

# Se elimina la columna review aplicando el metodo drop.
userReviewsFinal.drop('review', axis=1, inplace=True)

# %%
# Se realiza un recuento de cada puntaje para entender su distribución
userReviewsFinal['sentiment_analysis'].value_counts()
# Out:
# sentiment_analysis
# 2    36843
# 1    12132
# 0     9482
# Name: count, dtype: int64

# %%
# Se verifica la media de nulos en el dataset.
userReviewsFinal.isna().mean()
# Out:
# user_id               0.000000
# item_id               0.000445
# recommend             0.000445
# review_year           0.000000
# sentiment_analysis    0.000000
# dtype: float64

# %%
# Para evitar problemas futuros en la interpretación de datos al cargar el archivo csv se procede a eliminar los nulos en la columna item_id
#userReviewsFinal[userReviewsFinal['item_id'].isna() == True].count()

#userReviewsFinal["item_id"].fillna(0, inplace=True)

#userReviewsFinal[userReviewsFinal['item_id'] == 0]

# %%
userReviewsFinal.count()
# Out:
# user_id               58457
# item_id               58431
# recommend             58431
# review_year           58457
# sentiment_analysis    58457
# dtype: int64

# %%
userReviewsFinal[userReviewsFinal['item_id'] != 0]
# Out:
#                  user_id  item_id recommend  review_year  sentiment_analysis
# 0      76561197970982479     1250      True         2011                   2
# 1      76561197970982479    22200      True         2011                   2
# 2      76561197970982479    43110      True         2011                   2
# 3                js41637   251610      True         2014                   2
# 4                js41637   227300      True         2013                   2
# ...                  ...      ...       ...          ...                 ...
# 59328  76561198312638244       70      True         2015                   2
# 59329  76561198312638244   362890      True         2015                   2
# 59330        LydiaMorley   273110      True         2015                   2
# 59331        LydiaMorley      730      True         2015                   2
# 59332        LydiaMorley      440      True         2015                   2
#
# [58431 rows x 5 columns]

# %%
userReviewsFinal.rename(columns={'item_id': 'id'}, inplace=True)

# %%
userReviewsFinal.isna().mean()
# Out:
# user_id               0.000000
# id                    0.000445
# recommend             0.000445
# review_year           0.000000
# sentiment_analysis    0.000000
# dtype: float64

# %%
userReviewsFinal
# Out:
#                  user_id      id recommend  review_year  sentiment_analysis
# 0      76561197970982479    1250      True         2011                   2
# 1      76561197970982479   22200      True         2011                   2
# 2      76561197970982479   43110      True         2011                   2
# 3                js41637  251610      True         2014                   2
# 4                js41637  227300      True         2013                   2
# ...                  ...     ...       ...          ...                 ...
# 59328  76561198312638244      70      True         2015                   2
# 59329  76561198312638244  362890      True         2015                   2
# 59330        LydiaMorley  273110      True         2015                   2
# 59331        LydiaMorley     730      True         2015                   2
# 59332        LydiaMorley     440      True         2015                   2
#
# [58457 rows x 5 columns]

# %%
# Se guarda el dataset en csv para su posterior consumo
userReviewsFinal.to_csv('csv_limpios/user_reviews.csv', index= False)

# %%
# Se comprime en parquet

# Se convierte el DataFrame a una tabla de Arrow para posteriormente comprimirlo en parquet
table = pa.Table.from_pandas(userReviewsFinal)

# Especifica el nombre del archivo Parquet y comprime con snappy
parquet_file = 'datos_parquet/user_reviews.parquet'
pq.write_table(table, parquet_file, compression='snappy')
